# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np  
import csv 
import datetime as dt

# %%
zillow_11 = pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_11.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City  New York County   240504.0  ...
# 1          Chicago-Naperville-Elgin      Cook County   195485.0  ...
# 2       New York-Newark-Jersey City  New York County        NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County        NaN  ...
# 4          Chicago-Naperville-Elgin      Cook County   209865.0  ...
#
#    9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# 0    1272702     1272478     1270556     1269823    1268361    1267370
# 1     406557      405362      404016      403134     402705     403404
# 2    1793212     1792082     1791911     1790571    1790385    1787927
# 3     262450      262182      261771      261487     260876     260581
# 4     455882      455093      454120      453124     452720     452758
#
#    3/31/2020  4/30/2020  5/31/2020  6/30/2020
# 0    1264233    1261616    1257309    1254642
# 1     404434     405118     404920     404918
# 2    1784664    1780650    1776264    1774406
# 3     260567     261577     262679     263403
# 4     453321     452986     452355     451749
#
# [5 rows x 303 columns]

# %%
df_2bdr=pd.melt(zillow_11,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_2bdr.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
# 5     91940         5       77449        Zip        TX    TX      Katy
# 6     61616         6       10002        Zip        NY    NY  New York
# 7     91733         7       77084        Zip        TX    TX   Houston
# 8     93144         8       79936        Zip        TX    TX   El Paso
# 9     84640         9       60640        Zip        IL    IL   Chicago
#
#                               Metro       CountyName   variable     value
# 0       New York-Newark-Jersey City  New York County  1/31/1996  240504.0
# 1          Chicago-Naperville-Elgin      Cook County  1/31/1996  195485.0
# 2       New York-Newark-Jersey City  New York County  1/31/1996       NaN
# 3  Houston-The Woodlands-Sugar Land    Harris County  1/31/1996       NaN
# 4          Chicago-Naperville-Elgin      Cook County  1/31/1996  209865.0
# 5  Houston-The Woodlands-Sugar Land    Harris County  1/31/1996   67825.0
# 6       New York-Newark-Jersey City  New York County  1/31/1996  307036.0
# 7  Houston-The Woodlands-Sugar Land    Harris County  1/31/1996   70799.0
# 8                           El Paso   El Paso County  1/31/1996   66959.0
# 9          Chicago-Naperville-Elgin      Cook County  1/31/1996  117692.0

# %%
df_2bdr["type"]="2-bdr"
df_2bdr["variable"]=df_2bdr["variable"].astype('datetime64[m]')
df_2bdr["epoch"] = (df_2bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_2bdr=df_2bdr.dropna(how="any")
df_2bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 4           84616         4       60614        Zip        IL    IL
# 5           91940         5       77449        Zip        TX    TX
# 6           61616         6       10002        Zip        NY    NY
# ...           ...       ...         ...        ...       ...   ...
# 7918297     59376     34430        4109        Zip        ME    ME
# 7918298     95186     34430       86343        Zip        AZ    AZ
# 7918299     95851     34430       89155        Zip        NV    NV
# 7918300     98400     34430       95721        Zip        CA    CA
# 7918301     61694     34430       10118        Zip        NY    NY
#
#                  City                                Metro         CountyName  \
# 0            New York          New York-Newark-Jersey City    New York County
# 1             Chicago             Chicago-Naperville-Elgin        Cook County
# 4             Chicago             Chicago-Naperville-Elgin        Cook County
# 5                Katy     Houston-The Woodlands-Sugar Land      Harris County
# 6            New York          New York-Newark-Jersey City    New York County
# ...               ...                                  ...                ...
# 7918297      Portland              Portland-South Portland  Cumberland County
# 7918298    Crown King                             Prescott     Yavapai County
# 7918299     Las Vegas         Las Vegas-Henderson-Paradise       Clark County
# 7918300  Twin Bridges  Sacramento--Roseville--Arden-Arcade   El Dorado County
# 7918301      New York          New York-Newark-Jersey City    New York County
#
#           variable      value   type         epoch
# 0       1996-01-31   240504.0  2-bdr  8.230464e+08
# 1       1996-01-31   195485.0  2-bdr  8.230464e+08
# 4       1996-01-31   209865.0  2-bdr  8.230464e+08
# 5       1996-01-31    67825.0  2-bdr  8.230464e+08
# 6       1996-01-31   307036.0  2-bdr  8.230464e+08
# ...            ...        ...    ...           ...
# 7918297 2020-06-30   415439.0  2-bdr  1.593475e+09
# 7918298 2020-06-30   162475.0  2-bdr  1.593475e+09
# 7918299 2020-06-30   216217.0  2-bdr  1.593475e+09
# 7918300 2020-06-30   240154.0  2-bdr  1.593475e+09
# 7918301 2020-06-30  3168649.0  2-bdr  1.593475e+09
#
# [4814011 rows x 13 columns]

# %%
df_2bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 4           84616         4       60614        Zip        IL    IL
# 5           91940         5       77449        Zip        TX    TX
# 6           61616         6       10002        Zip        NY    NY
# ...           ...       ...         ...        ...       ...   ...
# 7918297     59376     34430        4109        Zip        ME    ME
# 7918298     95186     34430       86343        Zip        AZ    AZ
# 7918299     95851     34430       89155        Zip        NV    NV
# 7918300     98400     34430       95721        Zip        CA    CA
# 7918301     61694     34430       10118        Zip        NY    NY
#
#                  City                                Metro         CountyName  \
# 0            New York          New York-Newark-Jersey City    New York County
# 1             Chicago             Chicago-Naperville-Elgin        Cook County
# 4             Chicago             Chicago-Naperville-Elgin        Cook County
# 5                Katy     Houston-The Woodlands-Sugar Land      Harris County
# 6            New York          New York-Newark-Jersey City    New York County
# ...               ...                                  ...                ...
# 7918297      Portland              Portland-South Portland  Cumberland County
# 7918298    Crown King                             Prescott     Yavapai County
# 7918299     Las Vegas         Las Vegas-Henderson-Paradise       Clark County
# 7918300  Twin Bridges  Sacramento--Roseville--Arden-Arcade   El Dorado County
# 7918301      New York          New York-Newark-Jersey City    New York County
#
#           variable      value   type         epoch
# 0       1996-01-31   240504.0  2-bdr  8.230464e+08
# 1       1996-01-31   195485.0  2-bdr  8.230464e+08
# 4       1996-01-31   209865.0  2-bdr  8.230464e+08
# 5       1996-01-31    67825.0  2-bdr  8.230464e+08
# 6       1996-01-31   307036.0  2-bdr  8.230464e+08
# ...            ...        ...    ...           ...
# 7918297 2020-06-30   415439.0  2-bdr  1.593475e+09
# 7918298 2020-06-30   162475.0  2-bdr  1.593475e+09
# 7918299 2020-06-30   216217.0  2-bdr  1.593475e+09
# 7918300 2020-06-30   240154.0  2-bdr  1.593475e+09
# 7918301 2020-06-30  3168649.0  2-bdr  1.593475e+09
#
# [4814011 rows x 13 columns]

# %%
X11=df_2bdr["variable"].values.reshape(-1,1)
y11=df_2bdr["value"].values.reshape(-1,1)

X22=df_2bdr["epoch"].values.reshape(-1,1)
y22=df_2bdr["value"].values.reshape(-1,1)

# %%
plt.scatter(X11,y11)

# %%
# Prediction 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X22, y22, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, y_train)
model
X_test
# Out:
# array([[8.5976640e+08],
#        [1.1044512e+09],
#        [1.3147488e+09],
#        ...,
#        [9.1506240e+08],
#        [8.9916480e+08],
#        [1.5014592e+09]])

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 20870937377.15892
# R-squared (R2 ): 0.015888000665476687

# %%
model.predict(np.array([1596662122]).reshape(-1, 1))
# Out:
# array([[188322.09181862]])

# %%
##schools_data

schools_data= pd.read_csv('./Resources/number-of-schools.csv')
schools_data.head(10)
# Out:
#    index  objectid           city state    zip      county
# 0      0      2002     NEW SMYRNA    FL  32168     VOLUSIA
# 1      1      2003      WOODWORTH    LA  71485     RAPIDES
# 2      2      2004      BRUNSWICK    ME   4011  CUMBERLAND
# 3      3      2005       CARTHAGE    MS  39051       LEAKE
# 4      4      2006        KEARNEY    MO  64060        CLAY
# 5      5      2007        LINCOLN    NE  68516   LANCASTER
# 6      6      2008      LAS VEGAS    NV  89121       CLARK
# 7      7      2009      LAS VEGAS    NV  89141       CLARK
# 8      8      2010  ATLANTIC CITY    NJ   8401    ATLANTIC
# 9      9      2011      WESTFIELD    NJ   7090       UNION

# %%
nc_schols=schools_data[schools_data['state']=='NC']

# %%
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_schols_df
# Out:
#        zip  count
# 0    27006      2
# 1    27011      3
# 2    27012      4
# 3    27013      2
# 4    27014      1
# ..     ...    ...
# 620  28806     12
# 621  28901      3
# 622  28904      3
# 623  28905      1
# 624  28906     11
#
# [625 rows x 2 columns]

# %%
nc_df_2bdr=df_2bdr[df_2bdr['State']=='NC']
nc_df_2bdr.head(10)
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 32      69816        33       28269        Zip        NC    NC     Charlotte
# 55      69823        56       28277        Zip        NC    NC     Charlotte
# 85      69672        86       28027        Zip        NC    NC       Concord
# 139     69431       140       27587        Zip        NC    NC   Wake Forest
# 184     69699       186       28078        Zip        NC    NC  Huntersville
# 189     69450       191       27610        Zip        NC    NC       Raleigh
# 192     69340       194       27410        Zip        NC    NC    Greensboro
# 198     69336       200       27406        Zip        NC    NC    Greensboro
# 213     69849       215       28314        Zip        NC    NC  Fayetteville
# 318     69275       321       27284        Zip        NC    NC  Kernersville
#
#                           Metro          CountyName   variable     value  \
# 32   Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31   95370.0
# 55   Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  110940.0
# 85   Charlotte-Concord-Gastonia     Cabarrus County 1996-01-31   72122.0
# 139                     Raleigh         Wake County 1996-01-31  123620.0
# 184  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31   92287.0
# 189                     Raleigh         Wake County 1996-01-31  103623.0
# 192       Greensboro-High Point     Guilford County 1996-01-31   88150.0
# 198       Greensboro-High Point     Guilford County 1996-01-31   59689.0
# 213                Fayetteville   Cumberland County 1996-01-31   75123.0
# 318               Winston-Salem      Forsyth County 1996-01-31   78249.0
#
#       type        epoch
# 32   2-bdr  823046400.0
# 55   2-bdr  823046400.0
# 85   2-bdr  823046400.0
# 139  2-bdr  823046400.0
# 184  2-bdr  823046400.0
# 189  2-bdr  823046400.0
# 192  2-bdr  823046400.0
# 198  2-bdr  823046400.0
# 213  2-bdr  823046400.0
# 318  2-bdr  823046400.0

# %%
nc_df_2bdr.to_csv('nc_2bed.csv', index=False, header=True)

# %%
nc_df_2bdr=nc_df_2bdr.groupby(["City","RegionName"])["value"].mean().reset_index(name="avg")
nc_df_2bdr
# Out:
#             City  RegionName            avg
# 0       Aberdeen       28315   99995.515789
# 1        Advance       27006  132251.410811
# 2      Albemarle       28001   58202.006803
# 3      Alexander       28701  154195.583643
# 4         Alexis       28006  104531.237736
# ..           ...         ...            ...
# 597  Yadkinville       27055   86084.994565
# 598  Youngsville       27596  139581.902703
# 599      Zebulon       27597  103068.200692
# 600    Zionville       28698  157389.320000
# 601     Zirconia       28790  163618.933673
#
# [602 rows x 3 columns]

# %%
merge_data=pd.merge(nc_df_2bdr,nc_schols_df,left_on="RegionName",right_on="zip")

# %%
merge_data['City_category'] = merge_data['City'].astype('category').cat.codes
merge_data
# Out:
#                    City  RegionName            avg    zip  count  \
# 0              Aberdeen       28315   99995.515789  28315      4
# 1               Advance       27006  132251.410811  27006      2
# 2             Albemarle       28001   58202.006803  28001      8
# 3                Angier       27501  101196.766667  27501      5
# 4                  Apex       27502  155699.619863  27502      7
# ..                  ...         ...            ...    ...    ...
# 491  Wrightsville Beach       28480  603578.373626  28480      1
# 492         Yadkinville       27055   86084.994565  27055      4
# 493         Youngsville       27596  139581.902703  27596      3
# 494             Zebulon       27597  103068.200692  27597      5
# 495           Zionville       28698  157389.320000  28698      1
#
#      City_category
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ..             ...
# 491            371
# 492            372
# 493            373
# 494            374
# 495            375
#
# [496 rows x 6 columns]

# %%
X=merge_data["City_category"].values.reshape(-1,1)
y=merge_data["avg"].values.reshape(-1,1)

# %%
X=merge_data[["City_category"]]
y=merge_data["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.010257645906922463
# Testing Score: -0.01264493928206667

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
plt.scatter(y_test,predicted)
# Out:
# Mean Squared Error (MSE): 3996731909.1343126
# R-squared (R2 ): -0.01264493928206667

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
##income_data

income_data = pd.read_csv('./Resources/rw_census_data.csv')
income_data.head(10)
# Out:
#    population  poverty_count  median_household_income  zipcode  poverty_rate
# 0     17242.0        10772.0                  13092.0      601     62.475351
# 1     38442.0        19611.0                  16358.0      602     51.014515
# 2     48814.0        24337.0                  16603.0      603     49.856599
# 3      6437.0         4163.0                  12832.0      606     64.672984
# 4     27073.0        11724.0                  19309.0      610     43.305138
# 5     60303.0        28547.0                  18171.0      612     47.339270
# 6     10765.0         5388.0                  16018.0      616     50.051092
# 7     23974.0        11879.0                  16735.0      617     49.549512
# 8      6578.0         3309.0                  15206.0      622     50.304044
# 9     42427.0        22617.0                  16280.0      623     53.308035

# %%
merge_data2=pd.merge(merge_data,income_data,left_on="RegionName",right_on="zipcode")

merge_data2
# Out:
#                    City  RegionName            avg    zip  count  \
# 0              Aberdeen       28315   99995.515789  28315      4
# 1               Advance       27006  132251.410811  27006      2
# 2             Albemarle       28001   58202.006803  28001      8
# 3                Angier       27501  101196.766667  27501      5
# 4                  Apex       27502  155699.619863  27502      7
# ..                  ...         ...            ...    ...    ...
# 491  Wrightsville Beach       28480  603578.373626  28480      1
# 492         Yadkinville       27055   86084.994565  27055      4
# 493         Youngsville       27596  139581.902703  27596      3
# 494             Zebulon       27597  103068.200692  27597      5
# 495           Zionville       28698  157389.320000  28698      1
#
#      City_category  population  poverty_count  median_household_income  \
# 0                0     13700.0         2826.0                  51725.0
# 1                1     14555.0          932.0                  78095.0
# 2                2     26601.0         5208.0                  45121.0
# 3                3     21299.0         2601.0                  56338.0
# 4                4     40280.0         2248.0                 110513.0
# ..             ...         ...            ...                      ...
# 491            371      2536.0          216.0                  83417.0
# 492            372     14131.0         1855.0                  44574.0
# 493            373     18359.0         1624.0                  70535.0
# 494            374     23538.0         2995.0                  58514.0
# 495            375      2247.0          511.0                  42609.0
#
#      zipcode  poverty_rate
# 0      28315     20.627737
# 1      27006      6.403298
# 2      28001     19.578211
# 3      27501     12.211841
# 4      27502      5.580933
# ..       ...           ...
# 491    28480      8.517350
# 492    27055     13.127167
# 493    27596      8.845798
# 494    27597     12.724106
# 495    28698     22.741433
#
# [496 rows x 11 columns]

# %%
X=merge_data2[["City_category","population","median_household_income"]]
y=merge_data2["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.07297380392397346
# Testing Score: -0.01746822863794173

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 3579576546.1672893
# R-squared (R2 ): -0.01746822863794173

# %%
plt.scatter(y_test,predicted)

# %%
y_test
# Out:
# array([[ 76419.54081633],
#        [152113.86054422],
#        [136000.54077253],
#        [ 30385.63333333],
#        [ 79387.90707965],
#        [ 79095.58759124],
#        [ 90987.02040816],
#        [133210.2761194 ],
#        [ 88728.53401361],
#        [107964.64071856],
#        [ 58470.31441048],
#        [ 88553.76691729],
#        [116185.04761905],
#        [106915.57823129],
#        [ 92851.33333333],
#        [ 74149.76630435],
#        [101413.15816327],
#        [102069.07326007],
#        [146995.0982906 ],
#        [ 81011.93197279],
#        [ 72866.40816327],
#        [ 92864.93478261],
#        [ 82650.52941176],
#        [211772.04421769],
#        [ 77218.04887218],
#        [ 70106.23684211],
#        [ 51373.50853242],
#        [100729.65298507],
#        [165192.5       ],
#        [212048.07553957],
#        [ 35956.24489796],
#        [ 70714.77891156],
#        [ 49692.2244898 ],
#        [ 58202.00680272],
#        [ 84215.74489796],
#        [134058.90816327],
#        [154883.61734694],
#        [ 65794.31985294],
#        [112773.95918367],
#        [102752.22304833],
#        [ 52928.28804348],
#        [146277.23703704],
#        [ 82651.91176471],
#        [103068.20069204],
#        [ 99995.51578947],
#        [ 88896.01403509],
#        [ 52176.48818898],
#        [ 81507.71186441],
#        [ 94921.68367347],
#        [112555.75945737],
#        [101053.09843818],
#        [ 94128.15751459],
#        [111358.82726986],
#        [102999.00036016],
#        [ 97911.08228409],
#        [ 97447.55478638],
#        [109206.81378277],
#        [ 99823.22482128],
#        [ 93667.42721848],
#        [ 98320.45140056],
#        [111220.46438837],
#        [104057.9237448 ],
#        [104744.96141668],
#        [ 94120.74786658],
#        [110740.41277697],
#        [110490.70025927],
#        [ 96685.95493441],
#        [100668.34655668],
#        [ 94803.90258245],
#        [ 94759.64820185],
#        [107424.9093199 ],
#        [102539.12605456],
#        [ 95251.29076323],
#        [ 94549.02084418],
#        [100262.83577842],
#        [111901.12710705],
#        [100101.93479928],
#        [111042.2321252 ],
#        [111611.84915894],
#        [107794.68300065],
#        [ 98685.3969817 ],
#        [ 94186.14507818],
#        [ 98869.5960303 ],
#        [109924.56818459],
#        [101883.93402901],
#        [111093.41874703],
#        [111492.70285142],
#        [105412.8828663 ],
#        [109475.15118611],
#        [ 97201.74243738],
#        [ 93615.15979356],
#        [110430.38112828],
#        [106885.7553169 ],
#        [ 91894.95160658],
#        [111988.08580556],
#        [102957.32417019],
#        [ 95091.28360636],
#        [111062.46881726],
#        [113186.00185113],
#        [108691.11821103],
#        [110509.47370457],
#        [116664.88856358],
#        [ 92270.9455502 ],
#        [ 99598.61217033],
#        [114429.82790185],
#        [ 94789.88588654],
#        [ 97297.77611461],
#        [114452.5106503 ],
#        [107796.52057127],
#        [ 99269.30768428],
#        [102483.15287195],
#        [112068.92179701],
#        [ 93070.09809764],
#        [107003.07854288],
#        [111116.01742422],
#        [114400.27353877],
#        [ 92542.79195883],
#        [110511.3694631 ],
#        [112633.00623155],
#        [112705.43912321],
#        [ 93187.54169692],
#        [109314.94260532],
#        [107848.39693832],
#        [108092.61020618],
#        [106132.57548764],
#        [106967.30729884],
#        [ 94745.88977646],
#        [ 97633.95774835],
#        [102219.05210849],
#        [106405.2276302 ],
#        [107604.12298105],
#        [ 97344.35976658],
#        [106753.2459075 ],
#        [102495.63863627],
#        [112634.78922845],
#        [106295.88159577],
#        [105349.35373604],
#        [ 90696.90782391],
#        [ 93203.32132158],
#        [ 92740.52017344],
#        [108021.08635104],
#        [ 98317.36702389],
#        [106840.76081565],
#        [111961.22089583],
#        [110067.85680599],
#        [ 97347.08819631],
#        [104698.87998674],
#        [116251.58269799],
#        [ 96963.34934173],
#        [105751.92727073],
#        [105388.69425432]])

# %%
merge_data2.to_csv('merged_data_2bed.csv', index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-205-fa77c53537ff> in <module>
# ----> 1 merge_data2.to_csv('merged_data_2bed.csv', index=False, header=True)
#
# ~\Anaconda3_2\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3_2\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3_2\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'merged_data_2bed.csv'

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')
