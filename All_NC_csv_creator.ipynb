# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np  
import csv 
import datetime as dt

# %%
zillow_1 = pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_1.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     84616         4       60614        Zip        IL    IL   Chicago
# 4     91940         5       77449        Zip        TX    TX      Katy
#
#                               Metro       CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City  New York County   111258.0  ...
# 1          Chicago-Naperville-Elgin      Cook County   111421.0  ...
# 2       New York-Newark-Jersey City  New York County   189781.0  ...
# 3          Chicago-Naperville-Elgin      Cook County   128112.0  ...
# 4  Houston-The Woodlands-Sugar Land    Harris County    90479.0  ...
#
#    9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# ...

# %%
df_1bdr=pd.melt(zillow_1,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_1bdr.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     84616         4       60614        Zip        IL    IL   Chicago
# 4     91940         5       77449        Zip        TX    TX      Katy
# 5     61616         6       10002        Zip        NY    NY  New York
# 6     91733         7       77084        Zip        TX    TX   Houston
# 7     93144         8       79936        Zip        TX    TX   El Paso
# 8     84640         9       60640        Zip        IL    IL   Chicago
# 9     62037        10       11226        Zip        NY    NY  New York
#
#                               Metro       CountyName   variable     value
# 0       New York-Newark-Jersey City  New York County  1/31/1996  111258.0
# ...

# %%
df_1bdr["type"]="1-bdr"
df_1bdr["variable"]=df_1bdr["variable"].astype('datetime64[m]')
df_1bdr["epoch"] = (df_1bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_1bdr=df_1bdr.dropna(how="any")
df_1bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 2           61637         2       10023        Zip        NY    NY
# 3           84616         4       60614        Zip        IL    IL
# 4           91940         5       77449        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 5578645     93901     34322       82310        Zip        WY    WY
# 5578646     60206     34322        6230        Zip        CT    CT
# 5578647     58952     34322        2872        Zip        RI    RI
# 5578648     95186     34430       86343        Zip        AZ    AZ
# 5578649     59376     34430        4109        Zip        ME    ME
#
#                    City                             Metro         CountyName  \
# 0              New York       New York-Newark-Jersey City    New York County
# ...

# %%
schools_data= pd.read_csv('./Resources/number-of-schools.csv')
schools_data.head(10)
# Out:
#    index  objectid           city state    zip      county
# 0      0      2002     NEW SMYRNA    FL  32168     VOLUSIA
# 1      1      2003      WOODWORTH    LA  71485     RAPIDES
# 2      2      2004      BRUNSWICK    ME   4011  CUMBERLAND
# 3      3      2005       CARTHAGE    MS  39051       LEAKE
# 4      4      2006        KEARNEY    MO  64060        CLAY
# 5      5      2007        LINCOLN    NE  68516   LANCASTER
# 6      6      2008      LAS VEGAS    NV  89121       CLARK
# 7      7      2009      LAS VEGAS    NV  89141       CLARK
# 8      8      2010  ATLANTIC CITY    NJ   8401    ATLANTIC
# 9      9      2011      WESTFIELD    NJ   7090       UNION

# %%
nc_schols=schools_data[schools_data['state']=='NC']
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_df_1bdr=df_1bdr[df_1bdr['State']=='NC']
nc_df_1bdr.head(10)
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State  \
# 718      69197      9434       27052        Zip        NC    NC
# 787      69206      1475       27103        Zip        NC    NC
# 807      69209       651       27106        Zip        NC    NC
# 860      69210      1059       27107        Zip        NC    NC
# 878      69221      1660       27127        Zip        NC    NC
# 883      69233      5590       27203        Zip        NC    NC
# 891      69235      3033       27205        Zip        NC    NC
# 1560     69268      5341       27263        Zip        NC    NC
# 1561     69270       559       27265        Zip        NC    NC
# 1591     69273      6816       27282        Zip        NC    NC
#
#                City                  Metro       CountyName   variable  \
# 718     Walnut Cove          Winston-Salem    Stokes County 1996-01-31
# 787   Winston-Salem          Winston-Salem   Forsyth County 1996-01-31
# ...

# %%
nc_df_1bdr.to_csv('nc_1bed.csv', index=False, header=True)

# %%
zillow_3= pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_3.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City  New York County   976021.0  ...
# 1          Chicago-Naperville-Elgin      Cook County   257828.0  ...
# 2       New York-Newark-Jersey City  New York County        NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County   139236.0  ...
# 4          Chicago-Naperville-Elgin      Cook County   320113.0  ...
#
#    9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# ...

# %%
df_3bdr=pd.melt(zillow_3,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_3bdr.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
# 5     91940         5       77449        Zip        TX    TX      Katy
# 6     61616         6       10002        Zip        NY    NY  New York
# 7     91733         7       77084        Zip        TX    TX   Houston
# 8     93144         8       79936        Zip        TX    TX   El Paso
# 9     84640         9       60640        Zip        IL    IL   Chicago
#
#                               Metro       CountyName   variable     value
# 0       New York-Newark-Jersey City  New York County  1/31/1996  976021.0
# ...

# %%
df_3bdr["type"]="3-bdr"
df_3bdr["variable"]=df_3bdr["variable"].astype('datetime64[m]')
df_3bdr["epoch"] = (df_3bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_3bdr=df_3bdr.dropna(how="any")
df_3bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 3           91982         3       77494        Zip        TX    TX
# 4           84616         4       60614        Zip        IL    IL
# 5           91940         5       77449        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 8491008     98400     34430       95721        Zip        CA    CA
# 8491009     71534     34430       31421        Zip        GA    GA
# 8491011     69846     34430       28310        Zip        NC    NC
# 8491012     77449     34430       45114        Zip        OH    OH
# 8491013     95186     34430       86343        Zip        AZ    AZ
#
#                  City                                Metro         CountyName  \
# 0            New York          New York-Newark-Jersey City    New York County
# ...

# %%
nc_schols=schools_data[schools_data['state']=='NC']
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_df_3bdr=df_3bdr[df_3bdr['State']=='NC']
nc_df_3bdr.head(10)
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 32      69816        33       28269        Zip        NC    NC     Charlotte
# 55      69823        56       28277        Zip        NC    NC     Charlotte
# 85      69672        86       28027        Zip        NC    NC       Concord
# 139     69431       140       27587        Zip        NC    NC   Wake Forest
# 184     69699       186       28078        Zip        NC    NC  Huntersville
# 189     69450       191       27610        Zip        NC    NC       Raleigh
# 192     69340       194       27410        Zip        NC    NC    Greensboro
# 198     69336       200       27406        Zip        NC    NC    Greensboro
# 213     69849       215       28314        Zip        NC    NC  Fayetteville
# 319     69275       321       27284        Zip        NC    NC  Kernersville
#
#                           Metro          CountyName   variable     value  \
# ...

# %%
nc_df_3bdr.to_csv('nc_3bed.csv', index=False, header=True)

# %%
zillow_4= pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_4.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City  New York County        NaN  ...
# 1          Chicago-Naperville-Elgin      Cook County   398286.0  ...
# 2       New York-Newark-Jersey City  New York County        NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County   190908.0  ...
# 4          Chicago-Naperville-Elgin      Cook County   515152.0  ...
#
#    9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# ...

# %%
df_4bdr=pd.melt(zillow_4,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_4bdr.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
# 5     91940         5       77449        Zip        TX    TX      Katy
# 6     61616         6       10002        Zip        NY    NY  New York
# 7     91733         7       77084        Zip        TX    TX   Houston
# 8     93144         8       79936        Zip        TX    TX   El Paso
# 9     84640         9       60640        Zip        IL    IL   Chicago
#
#                               Metro       CountyName   variable     value
# 0       New York-Newark-Jersey City  New York County  1/31/1996       NaN
# ...

# %%
df_4bdr["type"]="4-bdr"
df_4bdr["variable"]=df_4bdr["variable"].astype('datetime64[m]')
df_4bdr["epoch"] = (df_4bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_4bdr=df_4bdr.dropna(how="any")
df_4bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 1           84654         1       60657        Zip        IL    IL
# 3           91982         3       77494        Zip        TX    TX
# 4           84616         4       60614        Zip        IL    IL
# 5           91940         5       77449        Zip        TX    TX
# 7           91733         7       77084        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 7870963     75095     34430       38959        Zip        MS    MS
# 7870964     58866     34430        2714        Zip        MA    MA
# 7870965     95186     34430       86343        Zip        AZ    AZ
# 7870966     66881     34430       21405        Zip        MD    MD
# 7870967     69440     34430       27599        Zip        NC    NC
#
#                City                             Metro           CountyName  \
# 1           Chicago          Chicago-Naperville-Elgin          Cook County
# ...

# %%
nc_schols=schools_data[schools_data['state']=='NC']
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_df_4bdr=df_4bdr[df_4bdr['State']=='NC']
nc_df_4bdr.head(10)
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 31      69816        33       28269        Zip        NC    NC     Charlotte
# 54      69823        56       28277        Zip        NC    NC     Charlotte
# 84      69672        86       28027        Zip        NC    NC       Concord
# 138     69431       140       27587        Zip        NC    NC   Wake Forest
# 183     69699       186       28078        Zip        NC    NC  Huntersville
# 188     69450       191       27610        Zip        NC    NC       Raleigh
# 191     69340       194       27410        Zip        NC    NC    Greensboro
# 197     69336       200       27406        Zip        NC    NC    Greensboro
# 212     69849       215       28314        Zip        NC    NC  Fayetteville
# 318     69275       321       27284        Zip        NC    NC  Kernersville
#
#                           Metro          CountyName   variable     value  \
# ...

# %%
nc_df_4bdr.to_csv('nc_4bed.csv', index=False, header=True)
