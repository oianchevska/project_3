# %% [markdown]
# ### Zip Code

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np  
import csv 
import datetime as dt

# %%
zillow_11 = pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_11.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     84616         4       60614        Zip        IL    IL   Chicago
# 4     91940         5       77449        Zip        TX    TX      Katy
# 5     61616         6       10002        Zip        NY    NY  New York
# 6     91733         7       77084        Zip        TX    TX   Houston
# 7     93144         8       79936        Zip        TX    TX   El Paso
# 8     84640         9       60640        Zip        IL    IL   Chicago
# 9     62037        10       11226        Zip        NY    NY  New York
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    111258.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    111421.0  ...
# 2       New York-Newark-Jersey City  New York County    189781.0  ...
# 3          Chicago-Naperville-Elgin      Cook County    128112.0  ...
# 4  Houston-The Woodlands-Sugar Land    Harris County     90479.0  ...
# 5       New York-Newark-Jersey City  New York County         NaN  ...
# 6  Houston-The Woodlands-Sugar Land    Harris County         NaN  ...
# 7                           El Paso   El Paso County     74403.0  ...
# 8          Chicago-Naperville-Elgin      Cook County     62131.0  ...
# 9       New York-Newark-Jersey City     Kings County    151024.0  ...
#
#    2019-09-30  2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 0    717134.0    715191.0    712496.0    710656.0    709822.0    710312.0
# 1    223303.0    222841.0    222420.0    222206.0    222280.0    222748.0
# 2    825711.0    822467.0    819524.0    817030.0    816480.0    814888.0
# 3    256844.0    256048.0    255162.0    254278.0    253906.0    254028.0
# 4    143300.0    144023.0    143852.0    144365.0    144387.0    144938.0
# 5    692782.0    691368.0    688776.0    690527.0    694984.0    702318.0
# 6     76696.0     77010.0     77095.0     77513.0     77262.0     76828.0
# 7    130489.0    130350.0    130363.0    130786.0    131182.0    131502.0
# 8    155396.0    155710.0    155849.0    155980.0    156448.0    157303.0
# 9    479406.0    478138.0    477714.0    475884.0    474922.0    473793.0
#
#    2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 0    711858.0    712502.0    712505.0    713185.0
# 1    223201.0    223501.0    223454.0    223662.0
# 2    813952.0    811516.0    810034.0    810253.0
# 3    254544.0    255105.0    255632.0    256315.0
# 4    145457.0    146069.0    146871.0    147265.0
# 5    707589.0    711584.0    713094.0    714139.0
# 6     76468.0     76502.0     76568.0     75959.0
# 7    131483.0    131478.0    131148.0    130523.0
# 8    157645.0    157386.0    156891.0    156711.0
# 9    474260.0    475278.0    475370.0    476007.0
#
# [10 rows x 303 columns]

# %%
df_1bdr=pd.melt(zillow_11,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_1bdr.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     84616         4       60614        Zip        IL    IL   Chicago
# 4     91940         5       77449        Zip        TX    TX      Katy
# 5     61616         6       10002        Zip        NY    NY  New York
# 6     91733         7       77084        Zip        TX    TX   Houston
# 7     93144         8       79936        Zip        TX    TX   El Paso
# 8     84640         9       60640        Zip        IL    IL   Chicago
# 9     62037        10       11226        Zip        NY    NY  New York
#
#                               Metro       CountyName    variable     value
# 0       New York-Newark-Jersey City  New York County  1996-01-31  111258.0
# 1          Chicago-Naperville-Elgin      Cook County  1996-01-31  111421.0
# 2       New York-Newark-Jersey City  New York County  1996-01-31  189781.0
# 3          Chicago-Naperville-Elgin      Cook County  1996-01-31  128112.0
# 4  Houston-The Woodlands-Sugar Land    Harris County  1996-01-31   90479.0
# 5       New York-Newark-Jersey City  New York County  1996-01-31       NaN
# 6  Houston-The Woodlands-Sugar Land    Harris County  1996-01-31       NaN
# 7                           El Paso   El Paso County  1996-01-31   74403.0
# 8          Chicago-Naperville-Elgin      Cook County  1996-01-31   62131.0
# 9       New York-Newark-Jersey City     Kings County  1996-01-31  151024.0

# %%
df_1bdr["type"]="1-bdr"
df_1bdr["variable"]=df_1bdr["variable"].astype('datetime64[m]')
df_1bdr["epoch"] = (df_1bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_1bdr=df_1bdr.dropna(how="any")
df_1bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 2           61637         2       10023        Zip        NY    NY
# 3           84616         4       60614        Zip        IL    IL
# 4           91940         5       77449        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 5578645     93901     34322       82310        Zip        WY    WY
# 5578646     60206     34322        6230        Zip        CT    CT
# 5578647     58952     34322        2872        Zip        RI    RI
# 5578648     95186     34430       86343        Zip        AZ    AZ
# 5578649     59376     34430        4109        Zip        ME    ME
#
#                    City                             Metro         CountyName  \
# 0              New York       New York-Newark-Jersey City    New York County
# 1               Chicago          Chicago-Naperville-Elgin        Cook County
# 2              New York       New York-Newark-Jersey City    New York County
# 3               Chicago          Chicago-Naperville-Elgin        Cook County
# 4                  Katy  Houston-The Woodlands-Sugar Land      Harris County
# ...                 ...                               ...                ...
# 5578645          Lander                          Riverton     Fremont County
# 5578646  Pomfret Center                         Worcester     Windham County
# 5578647      Portsmouth                Providence-Warwick     Newport County
# 5578648      Crown King                          Prescott     Yavapai County
# 5578649        Portland           Portland-South Portland  Cumberland County
#
#           variable     value   type         epoch
# 0       1996-01-31  111258.0  1-bdr  8.230464e+08
# 1       1996-01-31  111421.0  1-bdr  8.230464e+08
# 2       1996-01-31  189781.0  1-bdr  8.230464e+08
# 3       1996-01-31  128112.0  1-bdr  8.230464e+08
# 4       1996-01-31   90479.0  1-bdr  8.230464e+08
# ...            ...       ...    ...           ...
# 5578645 2020-06-30  122681.0  1-bdr  1.593475e+09
# 5578646 2020-06-30  171773.0  1-bdr  1.593475e+09
# 5578647 2020-06-30  204365.0  1-bdr  1.593475e+09
# 5578648 2020-06-30  118177.0  1-bdr  1.593475e+09
# 5578649 2020-06-30  469468.0  1-bdr  1.593475e+09
#
# [2925925 rows x 13 columns]

# %%
df_1bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 2           61637         2       10023        Zip        NY    NY
# 3           84616         4       60614        Zip        IL    IL
# 4           91940         5       77449        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 5578645     93901     34322       82310        Zip        WY    WY
# 5578646     60206     34322        6230        Zip        CT    CT
# 5578647     58952     34322        2872        Zip        RI    RI
# 5578648     95186     34430       86343        Zip        AZ    AZ
# 5578649     59376     34430        4109        Zip        ME    ME
#
#                    City                             Metro         CountyName  \
# 0              New York       New York-Newark-Jersey City    New York County
# 1               Chicago          Chicago-Naperville-Elgin        Cook County
# 2              New York       New York-Newark-Jersey City    New York County
# 3               Chicago          Chicago-Naperville-Elgin        Cook County
# 4                  Katy  Houston-The Woodlands-Sugar Land      Harris County
# ...                 ...                               ...                ...
# 5578645          Lander                          Riverton     Fremont County
# 5578646  Pomfret Center                         Worcester     Windham County
# 5578647      Portsmouth                Providence-Warwick     Newport County
# 5578648      Crown King                          Prescott     Yavapai County
# 5578649        Portland           Portland-South Portland  Cumberland County
#
#           variable     value   type         epoch
# 0       1996-01-31  111258.0  1-bdr  8.230464e+08
# 1       1996-01-31  111421.0  1-bdr  8.230464e+08
# 2       1996-01-31  189781.0  1-bdr  8.230464e+08
# 3       1996-01-31  128112.0  1-bdr  8.230464e+08
# 4       1996-01-31   90479.0  1-bdr  8.230464e+08
# ...            ...       ...    ...           ...
# 5578645 2020-06-30  122681.0  1-bdr  1.593475e+09
# 5578646 2020-06-30  171773.0  1-bdr  1.593475e+09
# 5578647 2020-06-30  204365.0  1-bdr  1.593475e+09
# 5578648 2020-06-30  118177.0  1-bdr  1.593475e+09
# 5578649 2020-06-30  469468.0  1-bdr  1.593475e+09
#
# [2925925 rows x 13 columns]

# %%
X11=df_1bdr["variable"].values.reshape(-1,1)
y11=df_1bdr["value"].values.reshape(-1,1)

X22=df_1bdr["epoch"].values.reshape(-1,1)
y22=df_1bdr["value"].values.reshape(-1,1)

# %%
plt.scatter(X11,y11)

# %%
# Prediction 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X22, y22, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, y_train)
model
X_test
# Out:
# array([[1.2069216e+09],
#        [1.2858048e+09],
#        [1.1307168e+09],
#        ...,
#        [1.1071296e+09],
#        [1.5303168e+09],
#        [1.2174624e+09]])

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 17981850607.378994
# R-squared (R2 ): 0.011814395848115167

# %%
model.predict(np.array([1596662122]).reshape(-1, 1))
# Out:
# array([[173092.8906526]])

# %% [markdown]
# ## schools_data

# %%
schools_data= pd.read_csv('./Resources/number-of-schools.csv')
schools_data.head(10)
# Out:
#    index  objectid           city state    zip      county
# 0      0      2002     NEW SMYRNA    FL  32168     VOLUSIA
# 1      1      2003      WOODWORTH    LA  71485     RAPIDES
# 2      2      2004      BRUNSWICK    ME   4011  CUMBERLAND
# 3      3      2005       CARTHAGE    MS  39051       LEAKE
# 4      4      2006        KEARNEY    MO  64060        CLAY
# 5      5      2007        LINCOLN    NE  68516   LANCASTER
# 6      6      2008      LAS VEGAS    NV  89121       CLARK
# 7      7      2009      LAS VEGAS    NV  89141       CLARK
# 8      8      2010  ATLANTIC CITY    NJ   8401    ATLANTIC
# 9      9      2011      WESTFIELD    NJ   7090       UNION

# %%
nc_schols=schools_data[schools_data['state']=='NC']

# %%
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_schols_df
# Out:
#        zip  count
# 0    27006      2
# 1    27011      3
# 2    27012      4
# 3    27013      2
# 4    27014      1
# ..     ...    ...
# 620  28806     12
# 621  28901      3
# 622  28904      3
# 623  28905      1
# 624  28906     11
#
# [625 rows x 2 columns]

# %%
nc_df_1bdr=df_1bdr[df_1bdr['State']=='NC']
nc_df_1bdr.head(10)
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 82      69672        86       28027        Zip        NC    NC       Concord
# 135     69431       140       27587        Zip        NC    NC   Wake Forest
# 179     69699       186       28078        Zip        NC    NC  Huntersville
# 184     69450       191       27610        Zip        NC    NC       Raleigh
# 187     69340       194       27410        Zip        NC    NC    Greensboro
# 309     69275       321       27284        Zip        NC    NC  Kernersville
# 417     69779       440       28216        Zip        NC    NC     Charlotte
# 491     69789       518       28227        Zip        NC    NC     Mint Hill
# 519     69773       548       28210        Zip        NC    NC     Charlotte
# 529     69270       559       27265        Zip        NC    NC    High Point
#
#                           Metro          CountyName   variable     value  \
# 82   Charlotte-Concord-Gastonia     Cabarrus County 1996-01-31   70873.0
# 135                     Raleigh         Wake County 1996-01-31  142540.0
# 179  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  122962.0
# 184                     Raleigh         Wake County 1996-01-31  124285.0
# 187       Greensboro-High Point     Guilford County 1996-01-31   55069.0
# 309               Winston-Salem      Forsyth County 1996-01-31   59771.0
# 417  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31   56219.0
# 491  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31   67702.0
# 519  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31   57011.0
# 529       Greensboro-High Point     Guilford County 1996-01-31   84129.0
#
#       type        epoch
# 82   1-bdr  823046400.0
# 135  1-bdr  823046400.0
# 179  1-bdr  823046400.0
# 184  1-bdr  823046400.0
# 187  1-bdr  823046400.0
# 309  1-bdr  823046400.0
# 417  1-bdr  823046400.0
# 491  1-bdr  823046400.0
# 519  1-bdr  823046400.0
# 529  1-bdr  823046400.0

# %%
nc_df_1bdr=nc_df_1bdr.groupby(["City","RegionName"])["value"].mean().reset_index(name="avg")
nc_df_1bdr
# Out:
#                    City  RegionName            avg
# 0              Aberdeen       28315  114560.250000
# 1               Advance       27006  117300.225275
# 2             Albemarle       28001   35063.496599
# 3             Alexander       28701  176274.226190
# 4                Angier       27501  126763.427083
# ..                  ...         ...            ...
# 462  Wrightsville Beach       28480  274212.242424
# 463         Youngsville       27596  100356.464865
# 464             Zebulon       27597  114133.758865
# 465           Zionville       28698  123630.137725
# 466            Zirconia       28790  158325.627551
#
# [467 rows x 3 columns]

# %%
merge_data=pd.merge(nc_df_1bdr,nc_schols_df,left_on="RegionName",right_on="zip")

# %%
merge_data
# Out:
#                    City  RegionName            avg    zip  count
# 0              Aberdeen       28315  114560.250000  28315      4
# 1               Advance       27006  117300.225275  27006      2
# 2             Albemarle       28001   35063.496599  28001      8
# 3                Angier       27501  126763.427083  27501      5
# 4                  Apex       27502  370912.251938  27502      7
# ..                  ...         ...            ...    ...    ...
# 401         Winterville       28590   57159.475000  28590      5
# 402  Wrightsville Beach       28480  274212.242424  28480      1
# 403         Youngsville       27596  100356.464865  27596      3
# 404             Zebulon       27597  114133.758865  27597      5
# 405           Zionville       28698  123630.137725  28698      1
#
# [406 rows x 5 columns]

# %%
X=merge_data["City"].values.reshape(-1,1)
y=merge_data["avg"].values.reshape(-1,1)

# %%
X=merge_data[["City"]]
y=merge_data["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.33004153950896764
# Testing Score: 0.2470446009488395

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
plt.scatter(y_test,predicted)
# Out:
# Mean Squared Error (MSE): 2316778707.553546
# R-squared (R2 ): 0.2470446009488395

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# ## income_data

# %%
income_data = pd.read_csv('./Resources/rw_census_data.csv')
income_data.head(10)
# Out:
#    population  poverty_count  median_household_income  zipcode  poverty_rate
# 0     17242.0        10772.0                  13092.0      601     62.475351
# 1     38442.0        19611.0                  16358.0      602     51.014515
# 2     48814.0        24337.0                  16603.0      603     49.856599
# 3      6437.0         4163.0                  12832.0      606     64.672984
# 4     27073.0        11724.0                  19309.0      610     43.305138
# 5     60303.0        28547.0                  18171.0      612     47.339270
# 6     10765.0         5388.0                  16018.0      616     50.051092
# 7     23974.0        11879.0                  16735.0      617     49.549512
# 8      6578.0         3309.0                  15206.0      622     50.304044
# 9     42427.0        22617.0                  16280.0      623     53.308035

# %%
merge_data2=pd.merge(merge_data,income_data,left_on="RegionName",right_on="zipcode")

merge_data2
# Out:
#                    City  RegionName            avg    zip  count  population  \
# 0              Aberdeen       28315  114560.250000  28315      4     13700.0
# 1               Advance       27006  117300.225275  27006      2     14555.0
# 2             Albemarle       28001   35063.496599  28001      8     26601.0
# 3                Angier       27501  126763.427083  27501      5     21299.0
# 4                  Apex       27502  370912.251938  27502      7     40280.0
# ..                  ...         ...            ...    ...    ...         ...
# 401         Winterville       28590   57159.475000  28590      5     24613.0
# 402  Wrightsville Beach       28480  274212.242424  28480      1      2536.0
# 403         Youngsville       27596  100356.464865  27596      3     18359.0
# 404             Zebulon       27597  114133.758865  27597      5     23538.0
# 405           Zionville       28698  123630.137725  28698      1      2247.0
#
#      poverty_count  median_household_income  zipcode  poverty_rate
# 0           2826.0                  51725.0    28315     20.627737
# 1            932.0                  78095.0    27006      6.403298
# 2           5208.0                  45121.0    28001     19.578211
# 3           2601.0                  56338.0    27501     12.211841
# 4           2248.0                 110513.0    27502      5.580933
# ..             ...                      ...      ...           ...
# 401         2747.0                  65594.0    28590     11.160769
# 402          216.0                  83417.0    28480      8.517350
# 403         1624.0                  70535.0    27596      8.845798
# 404         2995.0                  58514.0    27597     12.724106
# 405          511.0                  42609.0    28698     22.741433
#
# [406 rows x 10 columns]

# %%
X=merge_data2[["population","median_household_income"]]
y=merge_data2["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.33004153950896764
# Testing Score: 0.2470446009488395

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 2316778707.553546
# R-squared (R2 ): 0.2470446009488395

# %%
plt.scatter(y_test,predicted)

# %%
y_test
# Out:
# array([[ 67336.33333333],
#        [ 56526.40221402],
#        [180063.73      ],
#        [116456.64130435],
#        [124333.52631579],
#        [ 84262.74117647],
#        [ 22796.89719626],
#        [275774.83276451],
#        [ 80858.74054054],
#        [139166.52752294],
#        [105768.8436019 ],
#        [ 52637.74      ],
#        [135990.67692308],
#        [129484.33529412],
#        [ 64190.04761905],
#        [185640.12727273],
#        [ 42533.81395349],
#        [ 57886.75490196],
#        [ 76841.70408163],
#        [ 95631.87132353],
#        [176557.        ],
#        [ 57159.475     ],
#        [247360.02777778],
#        [125787.29811321],
#        [ 86661.83921569],
#        [ 68154.54      ],
#        [ 52360.74691358],
#        [163448.46994536],
#        [ 27082.46666667],
#        [120884.05970149],
#        [ 76601.23913043],
#        [134212.66666667],
#        [114560.25      ],
#        [ 94341.84615385],
#        [124724.25429553],
#        [ 69462.25170068],
#        [168895.375     ],
#        [110048.64130435],
#        [ 93305.25373134],
#        [ 84123.54266212],
#        [131526.18707483],
#        [ 65951.55172414],
#        [ 68857.87407407],
#        [175964.57322176],
#        [157054.99659864],
#        [ 54083.27333333],
#        [ 47195.71111111],
#        [ 23421.08888889],
#        [ 65990.085     ],
#        [ 68732.96052632],
#        [ 79557.96644295],
#        [136203.5       ],
#        [ 69466.85375494],
#        [219998.85      ],
#        [ 76280.36956522],
#        [141256.25      ],
#        [ 98745.        ],
#        [116392.23232323],
#        [ 63616.90909091],
#        [ 86253.92156863],
#        [161566.81292517],
#        [123363.9673913 ],
#        [111977.53061224],
#        [ 75232.85714286],
#        [ 92045.16788321],
#        [124852.77272727],
