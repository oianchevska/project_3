# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np  
import csv 
import datetime as dt

# %%
zillow_11 = pd.read_csv('./Resources/Zip_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
zillow_11.head(10)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
# 5     91940         5       77449        Zip        TX    TX      Katy
# 6     91733         7       77084        Zip        TX    TX   Houston
# 7     93144         8       79936        Zip        TX    TX   El Paso
# 8     84640         9       60640        Zip        IL    IL   Chicago
# 9     62037        10       11226        Zip        NY    NY  New York
#
#                               Metro       CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City  New York County        NaN  ...
# 1          Chicago-Naperville-Elgin      Cook County        NaN  ...
# 2       New York-Newark-Jersey City  New York County        NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County   249879.0  ...
# 4          Chicago-Naperville-Elgin      Cook County   735019.0  ...
# 5  Houston-The Woodlands-Sugar Land    Harris County   125650.0  ...
# 6  Houston-The Woodlands-Sugar Land    Harris County   134071.0  ...
# 7                           El Paso   El Paso County   175495.0  ...
# 8          Chicago-Naperville-Elgin      Cook County   319851.0  ...
# 9       New York-Newark-Jersey City     Kings County        NaN  ...
#
#     9/30/2019  10/31/2019  11/30/2019  12/31/2019   1/31/2020   2/29/2020  \
# 0   3448246.0   3435998.0   3395436.0   3357463.0   3357765.0   3416324.0
# 1   1515372.0   1512706.0   1509594.0   1507032.0   1507035.0   1508901.0
# 2  10200000.0  10100000.0  10100000.0  10100000.0  10200000.0  10100000.0
# 3    465177.0    465458.0    465855.0    466333.0    466032.0    466292.0
# 4   1948791.0   1943860.0   1936691.0   1932635.0   1929663.0   1932982.0
# 5    227285.0    227512.0    228683.0    229982.0    230665.0    231093.0
# 6    245648.0    246159.0    247228.0    248313.0    248786.0    249332.0
# 7    276744.0    276231.0    276205.0    277417.0    278646.0    279670.0
# 8   1169516.0   1165661.0   1161165.0   1157192.0   1155245.0   1154816.0
# 9   1572176.0   1576771.0   1580030.0   1585439.0   1582513.0   1581587.0
#
#    3/31/2020  4/30/2020  5/31/2020  6/30/2020
# 0  3469544.0  3484173.0  3510843.0  3586703.0
# 1  1511288.0  1512041.0  1511849.0  1512165.0
# 2  9884157.0  9684741.0  9568966.0  9571718.0
# 3   467250.0   468965.0   470630.0   471645.0
# 4  1934695.0  1935368.0  1933888.0  1936368.0
# 5   232282.0   233769.0   234656.0   235054.0
# 6   250468.0   251636.0   252444.0   252709.0
# 7   279803.0   279387.0   278320.0   277014.0
# 8  1155106.0  1152653.0  1153005.0  1150087.0
# 9  1583231.0  1588249.0  1591833.0  1591127.0
#
# [10 rows x 303 columns]

# %%
df_5bdr=pd.melt(zillow_11,id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City','Metro', 'CountyName']) 
df_5bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 0           61639         0       10025        Zip        NY    NY
# 1           84654         1       60657        Zip        IL    IL
# 2           61637         2       10023        Zip        NY    NY
# 3           91982         3       77494        Zip        TX    TX
# 4           84616         4       60614        Zip        IL    IL
# ...           ...       ...         ...        ...       ...   ...
# 6592651     66881     34430       21405        Zip        MD    MD
# 6592652     59376     34430        4109        Zip        ME    ME
# 6592653     59316     34430        4033        Zip        ME    ME
# 6592654     95851     34430       89155        Zip        NV    NV
# 6592655     66169     34430       20052        Zip        DC    DC
#
#                City                             Metro            CountyName  \
# 0          New York       New York-Newark-Jersey City       New York County
# 1           Chicago          Chicago-Naperville-Elgin           Cook County
# 2          New York       New York-Newark-Jersey City       New York County
# 3              Katy  Houston-The Woodlands-Sugar Land         Harris County
# 4           Chicago          Chicago-Naperville-Elgin           Cook County
# ...             ...                               ...                   ...
# 6592651   Annapolis         Baltimore-Columbia-Towson   Anne Arundel County
# 6592652    Portland           Portland-South Portland     Cumberland County
# 6592653  Cumberland           Portland-South Portland     Cumberland County
# 6592654   Las Vegas      Las Vegas-Henderson-Paradise          Clark County
# 6592655  Washington   Washington-Arlington-Alexandria  District of Columbia
#
#           variable      value
# 0        1/31/1996        NaN
# 1        1/31/1996        NaN
# 2        1/31/1996        NaN
# 3        1/31/1996   249879.0
# 4        1/31/1996   735019.0
# ...            ...        ...
# 6592651  6/30/2020  1194706.0
# 6592652  6/30/2020   880405.0
# 6592653  6/30/2020  1026942.0
# 6592654  6/30/2020   430695.0
# 6592655  6/30/2020  1398239.0
#
# [6592656 rows x 11 columns]

# %%
df_5bdr["type"]="5-bdr"
df_5bdr["variable"]=df_5bdr["variable"].astype('datetime64[m]')
df_5bdr["epoch"] = (df_5bdr["variable"] - dt.datetime(1970,1,1)).dt.total_seconds()
df_5bdr=df_5bdr.dropna(how="any")
df_5bdr
# Out:
#          RegionID  SizeRank  RegionName RegionType StateName State  \
# 3           91982         3       77494        Zip        TX    TX
# 4           84616         4       60614        Zip        IL    IL
# 5           91940         5       77449        Zip        TX    TX
# 6           91733         7       77084        Zip        TX    TX
# 7           93144         8       79936        Zip        TX    TX
# ...           ...       ...         ...        ...       ...   ...
# 6592651     66881     34430       21405        Zip        MD    MD
# 6592652     59376     34430        4109        Zip        ME    ME
# 6592653     59316     34430        4033        Zip        ME    ME
# 6592654     95851     34430       89155        Zip        NV    NV
# 6592655     66169     34430       20052        Zip        DC    DC
#
#                City                             Metro            CountyName  \
# 3              Katy  Houston-The Woodlands-Sugar Land         Harris County
# 4           Chicago          Chicago-Naperville-Elgin           Cook County
# 5              Katy  Houston-The Woodlands-Sugar Land         Harris County
# 6           Houston  Houston-The Woodlands-Sugar Land         Harris County
# 7           El Paso                           El Paso        El Paso County
# ...             ...                               ...                   ...
# 6592651   Annapolis         Baltimore-Columbia-Towson   Anne Arundel County
# 6592652    Portland           Portland-South Portland     Cumberland County
# 6592653  Cumberland           Portland-South Portland     Cumberland County
# 6592654   Las Vegas      Las Vegas-Henderson-Paradise          Clark County
# 6592655  Washington   Washington-Arlington-Alexandria  District of Columbia
#
#           variable      value   type         epoch
# 3       1996-01-31   249879.0  5-bdr  8.230464e+08
# 4       1996-01-31   735019.0  5-bdr  8.230464e+08
# 5       1996-01-31   125650.0  5-bdr  8.230464e+08
# 6       1996-01-31   134071.0  5-bdr  8.230464e+08
# 7       1996-01-31   175495.0  5-bdr  8.230464e+08
# ...            ...        ...    ...           ...
# 6592651 2020-06-30  1194706.0  5-bdr  1.593475e+09
# 6592652 2020-06-30   880405.0  5-bdr  1.593475e+09
# 6592653 2020-06-30  1026942.0  5-bdr  1.593475e+09
# 6592654 2020-06-30   430695.0  5-bdr  1.593475e+09
# 6592655 2020-06-30  1398239.0  5-bdr  1.593475e+09
#
# [4296471 rows x 13 columns]

# %%
X11=df_5bdr["variable"].values.reshape(-1,1)
y11=df_5bdr["value"].values.reshape(-1,1)

X22=df_5bdr["epoch"].values.reshape(-1,1)
y22=df_5bdr["value"].values.reshape(-1,1)

# %%
plt.scatter(X11,y11)

# %%
# Prediction 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X22, y22, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, y_train)
model
X_test
# Out:
# array([[1.5750720e+09],
#        [1.4831424e+09],
#        [1.4014944e+09],
#        ...,
#        [1.5565824e+09],
#        [1.2595392e+09],
#        [1.2463200e+09]])

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 4.707297312281571e+16
# R-squared (R2 ): -1687441.0718447112

# %%
model.predict(np.array([1596662122]).reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-295-b4ddaffc7067> in <module>
# ----> 1 model.predict(np.array([1596662122]).reshape(-1, 1))
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 5 is different from 1)

# %% [markdown]
# Schools Data

# %%
schools_data= pd.read_csv('./Resources/number-of-schools.csv')
schools_data.head(10)
# Out:
#    index  objectid           city state    zip      county
# 0      0      2002     NEW SMYRNA    FL  32168     VOLUSIA
# 1      1      2003      WOODWORTH    LA  71485     RAPIDES
# 2      2      2004      BRUNSWICK    ME   4011  CUMBERLAND
# 3      3      2005       CARTHAGE    MS  39051       LEAKE
# 4      4      2006        KEARNEY    MO  64060        CLAY
# 5      5      2007        LINCOLN    NE  68516   LANCASTER
# 6      6      2008      LAS VEGAS    NV  89121       CLARK
# 7      7      2009      LAS VEGAS    NV  89141       CLARK
# 8      8      2010  ATLANTIC CITY    NJ   8401    ATLANTIC
# 9      9      2011      WESTFIELD    NJ   7090       UNION

# %%
nc_schols=schools_data[schools_data['state']=='NC']

# %%
nc_schols_df=nc_schols.groupby("zip")["objectid"].count().reset_index(name="count")
nc_schols_df
# Out:
#        zip  count
# 0    27006      2
# 1    27011      3
# 2    27012      4
# 3    27013      2
# 4    27014      1
# ..     ...    ...
# 620  28806     12
# 621  28901      3
# 622  28904      3
# 623  28905      1
# 624  28906     11
#
# [625 rows x 2 columns]

# %%
nc_df_5bdr=df_5bdr[df_5bdr['State']=='NC']
nc_df_5bdr.head(10)
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 30      69816        33       28269        Zip        NC    NC     Charlotte
# 53      69823        56       28277        Zip        NC    NC     Charlotte
# 83      69672        86       28027        Zip        NC    NC       Concord
# 182     69699       186       28078        Zip        NC    NC  Huntersville
# 190     69340       194       27410        Zip        NC    NC    Greensboro
# 196     69336       200       27406        Zip        NC    NC    Greensboro
# 211     69849       215       28314        Zip        NC    NC  Fayetteville
# 317     69275       321       27284        Zip        NC    NC  Kernersville
# 400     69768       404       28205        Zip        NC    NC     Charlotte
# 409     70056       412       28601        Zip        NC    NC       Hickory
#
#                           Metro          CountyName   variable     value  \
# 30   Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  208878.0
# 53   Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  328832.0
# 83   Charlotte-Concord-Gastonia     Cabarrus County 1996-01-31  207069.0
# 182  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  258792.0
# 190       Greensboro-High Point     Guilford County 1996-01-31  241021.0
# 196       Greensboro-High Point     Guilford County 1996-01-31  185261.0
# 211                Fayetteville   Cumberland County 1996-01-31  169930.0
# 317               Winston-Salem      Forsyth County 1996-01-31  200285.0
# 400  Charlotte-Concord-Gastonia  Mecklenburg County 1996-01-31  264356.0
# 409    Hickory-Lenoir-Morganton      Catawba County 1996-01-31  235166.0
#
#       type        epoch
# 30   5-bdr  823046400.0
# 53   5-bdr  823046400.0
# 83   5-bdr  823046400.0
# 182  5-bdr  823046400.0
# 190  5-bdr  823046400.0
# 196  5-bdr  823046400.0
# 211  5-bdr  823046400.0
# 317  5-bdr  823046400.0
# 400  5-bdr  823046400.0
# 409  5-bdr  823046400.0

# %%
nc_df_5bdr=nc_df_5bdr.groupby(["City","RegionName"])["value"].mean().reset_index(name="avg")
nc_df_5bdr
# Out:
#             City  RegionName            avg
# 0       Aberdeen       28315  256666.107143
# 1        Advance       27006  420614.217391
# 2      Albemarle       28001  193832.969388
# 3      Alexander       28701  387356.405797
# 4         Alexis       28006  327069.064516
# ..           ...         ...            ...
# 540  Yadkinville       27055  239051.993333
# 541  Youngsville       27596  290807.523810
# 542      Zebulon       27597  228846.389078
# 543    Zionville       28698  852329.142857
# 544     Zirconia       28790  485792.816327
#
# [545 rows x 3 columns]

# %%
merge_data=pd.merge(nc_df_5bdr,nc_schols_df,left_on="RegionName",right_on="zip")
merge_data
# Out:
#                    City  RegionName           avg    zip  count
# 0              Aberdeen       28315  2.566661e+05  28315      4
# 1               Advance       27006  4.206142e+05  27006      2
# 2             Albemarle       28001  1.938330e+05  28001      8
# 3                Angier       27501  2.580105e+05  27501      5
# 4                  Apex       27502  3.770457e+05  27502      7
# ..                  ...         ...           ...    ...    ...
# 466  Wrightsville Beach       28480  1.574379e+06  28480      1
# 467         Yadkinville       27055  2.390520e+05  27055      4
# 468         Youngsville       27596  2.908075e+05  27596      3
# 469             Zebulon       27597  2.288464e+05  27597      5
# 470           Zionville       28698  8.523291e+05  28698      1
#
# [471 rows x 5 columns]

# %%
merge_data["City_Category"] = merge_data['City'].astype('category').cat.codes
merge_data
# Out:
#                    City  RegionName           avg    zip  count  City_Category
# 0              Aberdeen       28315  2.566661e+05  28315      4              0
# 1               Advance       27006  4.206142e+05  27006      2              1
# 2             Albemarle       28001  1.938330e+05  28001      8              2
# 3                Angier       27501  2.580105e+05  27501      5              3
# 4                  Apex       27502  3.770457e+05  27502      7              4
# ..                  ...         ...           ...    ...    ...            ...
# 466  Wrightsville Beach       28480  1.574379e+06  28480      1            347
# 467         Yadkinville       27055  2.390520e+05  27055      4            348
# 468         Youngsville       27596  2.908075e+05  27596      3            349
# 469             Zebulon       27597  2.288464e+05  27597      5            350
# 470           Zionville       28698  8.523291e+05  28698      1            351
#
# [471 rows x 6 columns]

# %%
X=merge_data[["City_Category", "count"]]
y=merge_data["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.03864345467316321
# Testing Score: -0.057126209110121

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
plt.scatter(y_test,predicted)
# Out:
# Mean Squared Error (MSE): 36637028868.084045
# R-squared (R2 ): -0.05712620911012101

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# INCOME DATA

# %%
income_data = pd.read_csv('./Resources/rw_census_data.csv')
income_data.head(10)
# Out:
#    population  poverty_count  median_household_income  zipcode  poverty_rate
# 0     17242.0        10772.0                  13092.0      601     62.475351
# 1     38442.0        19611.0                  16358.0      602     51.014515
# 2     48814.0        24337.0                  16603.0      603     49.856599
# 3      6437.0         4163.0                  12832.0      606     64.672984
# 4     27073.0        11724.0                  19309.0      610     43.305138
# 5     60303.0        28547.0                  18171.0      612     47.339270
# 6     10765.0         5388.0                  16018.0      616     50.051092
# 7     23974.0        11879.0                  16735.0      617     49.549512
# 8      6578.0         3309.0                  15206.0      622     50.304044
# 9     42427.0        22617.0                  16280.0      623     53.308035

# %%
merge_data2=pd.merge(merge_data,income_data,left_on="RegionName",right_on="zipcode")

merge_data2
# Out:
#                    City  RegionName           avg    zip  count  \
# 0              Aberdeen       28315  2.566661e+05  28315      4
# 1               Advance       27006  4.206142e+05  27006      2
# 2             Albemarle       28001  1.938330e+05  28001      8
# 3                Angier       27501  2.580105e+05  27501      5
# 4                  Apex       27502  3.770457e+05  27502      7
# ..                  ...         ...           ...    ...    ...
# 466  Wrightsville Beach       28480  1.574379e+06  28480      1
# 467         Yadkinville       27055  2.390520e+05  27055      4
# 468         Youngsville       27596  2.908075e+05  27596      3
# 469             Zebulon       27597  2.288464e+05  27597      5
# 470           Zionville       28698  8.523291e+05  28698      1
#
#      City_Category  population  poverty_count  median_household_income  \
# 0                0     13700.0         2826.0                  51725.0
# 1                1     14555.0          932.0                  78095.0
# 2                2     26601.0         5208.0                  45121.0
# 3                3     21299.0         2601.0                  56338.0
# 4                4     40280.0         2248.0                 110513.0
# ..             ...         ...            ...                      ...
# 466            347      2536.0          216.0                  83417.0
# 467            348     14131.0         1855.0                  44574.0
# 468            349     18359.0         1624.0                  70535.0
# 469            350     23538.0         2995.0                  58514.0
# 470            351      2247.0          511.0                  42609.0
#
#      zipcode  poverty_rate
# 0      28315     20.627737
# 1      27006      6.403298
# 2      28001     19.578211
# 3      27501     12.211841
# 4      27502      5.580933
# ..       ...           ...
# 466    28480      8.517350
# 467    27055     13.127167
# 468    27596      8.845798
# 469    27597     12.724106
# 470    28698     22.741433
#
# [471 rows x 11 columns]

# %%
X=merge_data2[["City_Category","population","median_household_income", "count", "poverty_rate"]]
y=merge_data2["avg"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.2551783853053936
# Testing Score: -1687441.0718447112

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score
### BEGIN SOLUTION
# Use our model to make predictions
predicted = model.predict(X_test)
# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# ### END SOLUTION
# Out:
# Mean Squared Error (MSE): 4.707297312281571e+16
# R-squared (R2 ): -1687441.0718447112

# %%
plt.scatter(y_test,predicted)

# %%
y_test
# Out:
# array([[ 469885.60750853],
#        [ 867579.36394558],
#        [ 362296.90740741],
#        [ 239949.48529412],
#        [ 200103.84848485],
#        [ 592818.98615917],
#        [ 103154.45454545],
#        [ 226773.18539326],
#        [ 229441.44274809],
#        [ 155125.34013605],
#        [ 221768.79931973],
#        [ 290656.27040816],
#        [ 324200.335     ],
#        [ 456652.74489796],
#        [ 248174.02040816],
#        [ 209092.24829932],
#        [ 155782.97435897],
#        [ 341737.45578231],
#        [ 263747.66666667],
#        [ 224243.15306122],
#        [ 256666.10714286],
#        [1574379.17460317],
#        [ 309547.90877193],
#        [ 340764.49519231],
#        [ 256989.93877551],
#        [ 368927.79359431],
#        [  88032.33992095],
#        [ 218627.49319728],
#        [ 220017.70588235],
#        [ 330147.09137056],
#        [ 171882.98130841],
#        [ 155988.77102804],
#        [ 213872.57575758],
#        [ 346071.00340136],
#        [  64389.75641026],
#        [ 336982.39673913],
#        [ 151464.39115646],
#        [ 282644.21428571],
#        [ 294806.19727891],
#        [ 119702.85034014],
#        [ 314811.08648649],
#        [ 202163.625     ],
#        [ 295813.52040816],
#        [ 239892.8707483 ],
#        [ 335992.61507937],
#        [ 168713.99333333],
#        [ 274251.76556777],
#        [ 569513.04761905],
#        [ 174655.17346939],
#        [ 307278.61921708],
#        [ 307908.63586957],
#        [ 276465.21768707],
#        [ 337780.37628866],
#        [ 510669.83695652],
#        [ 456179.29577465],
#        [ 210560.00512821],
#        [ 148122.25170068],
#        [ 197021.68359375],
#        [ 587185.95306859],
#        [ 467258.92346939],
#        [ 156935.89795918],
#        [ 595790.79310345],
#        [ 462767.55102041],
#        [ 538408.03636364],
#        [ 264169.90816327],
#        [ 416542.02941176],
#        [ 208880.23809524],
#        [ 201649.47037037],
#        [  78729.04026846],
#        [ 523158.79820628],
#        [ 278557.60474308],
#        [ 378176.99259259],
#        [ 165581.30722892],
#        [ 109850.66666667],
#        [ 150596.15789474],
#        [ 347209.61497326],
#        [ 286201.57482993],
#        [ 472016.54266212],
#        [ 103647.58163265],
#        [  91462.79069767],
#        [ 449543.32191781],
#        [ 258582.79925651],
#        [ 144177.05442177],
#        [ 118398.4375    ],
#        [ 485482.7283237 ],
#        [ 277754.91287879],
#        [ 189460.55555556],
#        [ 265820.6122449 ],
#        [ 257468.05782313],
#        [ 326929.71428571],
#        [ 108974.77272727],
#        [ 142849.96938776],
#        [ 279472.0952381 ],
#        [  61586.64166667],
#        [ 262199.02040816],
#        [ 242932.18027211],
#        [ 186723.19672131],
#        [ 299359.98814229],
#        [ 159063.48639456],
#        [  79489.94217687],
#        [ 244747.02666667],
#        [ 445299.62962963],
#        [ 265897.86394558],
#        [ 448299.94217687],
#        [ 281516.52380952],
#        [ 418228.68774704],
#        [  87838.38095238],
#        [ 310414.31884058],
#        [ 157060.96062992],
#        [ 566235.40136054],
#        [ 139584.89671362],
#        [ 328746.15646259],
#        [ 157106.38095238],
#        [ 254504.67687075],
#        [ 304900.93537415],
#        [ 111217.24242424],
#        [ 218679.60606061],
#        [ 697655.99212598],
#        [ 255308.43122677],
#        [ 252902.35687732],
#        [ 229032.02040816],
#        [ 265929.00917431],
#        [ 289671.30452675],
#        [ 190922.91496599],
#        [ 130920.28571429],
#        [ 723563.92517007],
#        [ 237608.54      ],
#        [ 182440.2755102 ],
#        [ 395582.14726027],
#        [ 239274.90860215],
#        [ 316386.89795918],
#        [ 282729.16666667],
#        [ 228846.3890785 ],
#        [ 646228.62847222],
#        [ 258010.46632124],
#        [ 246672.52280702],
#        [ 379103.18027211],
#        [ 161259.29770992],
#        [ 271970.35034014],
#        [ 206434.65938865],
#        [ 242297.81881533],
#        [ 243815.39393939],
#        [ 410892.97619048],
#        [ 115611.00884956],
#        [ 178863.41156463],
#        [ 329459.78061224],
#        [ 420824.61413043],
#        [ 340961.63333333],
#        [ 366159.21111111],
#        [ 219311.27027027],
#        [ 312585.27210884],
#        [ 183486.05860806],
#        [ 240942.77900552],
#        [ 356457.98924731],
#        [ 290807.52380952],
#        [  58111.67346939],
#        [ 286306.171875  ],
#        [ 167865.98529412],
#        [ 157798.5       ],
#        [ 299944.92517007],
#        [ 365499.57823129],
#        [ 176046.71034483],
#        [ 113703.95454545],
#        [ 226575.18027211],
#        [ 167454.29591837],
#        [ 741347.84615385],
#        [ 519661.45634921],
#        [ 366129.49166667],
#        [ 440825.10204082],
#        [ 275769.22789116],
#        [ 364198.33703704],
#        [ 259427.63978495],
#        [ 216872.27272727],
#        [ 313088.01621622],
#        [ 446639.4047619 ],
#        [ 228482.8968254 ],
#        [ 191305.92517007],
#        [ 418025.86734694],
#        [ 190195.94117647],
#        [ 166886.93197279],
#        [ 466301.83858268],
#        [ 106082.07428571],
#        [ 323565.25510204],
#        [ 289522.27758007],
#        [ 249834.26285714],
#        [ 152123.68421053],
#        [ 231774.66847826],
#        [ 248694.9829932 ],
#        [ 436275.84020619]])

# %%
predicted
# Out:
# array([[ 4.96624599e+05],
#        [ 4.53593400e+05],
#        [ 3.10527061e+05],
#        [ 3.39529914e+05],
#        [ 2.20693663e+05],
#        [ 3.33305569e+05],
#        [ 1.97526966e+05],
#        [ 3.50200909e+05],
#        [ 2.98776133e+05],
#        [ 2.09108829e+05],
#        [ 2.85835288e+05],
#        [ 2.64862198e+05],
#        [ 2.65413714e+05],
#        [ 2.97993481e+05],
#        [ 3.64128354e+05],
#        [ 1.89078483e+05],
#        [ 1.95874598e+05],
#        [ 4.51980783e+05],
#        [ 2.51097543e+05],
#        [ 2.80418802e+05],
#        [ 3.30969526e+05],
#        [ 4.15534567e+05],
#        [ 2.95525031e+05],
#        [ 3.03715935e+05],
#        [ 3.44299890e+05],
#        [ 3.65390153e+05],
#        [ 1.37825973e+05],
#        [ 2.77472221e+05],
#        [ 3.00273642e+05],
#        [ 2.38905838e+05],
#        [ 2.55780283e+05],
#        [ 2.35875029e+05],
#        [ 2.55555113e+05],
#        [ 3.20546056e+05],
#        [ 2.80461558e+05],
#        [ 2.96055800e+05],
#        [ 1.96273585e+05],
#        [ 3.13763945e+05],
#        [ 4.45612034e+05],
#        [ 1.44739496e+05],
#        [ 2.49400387e+05],
#        [ 1.94713863e+05],
#        [ 4.11899996e+05],
#        [ 1.95141871e+05],
#        [ 1.96744831e+05],
#        [ 2.03466050e+05],
#        [ 3.03979527e+05],
#        [ 3.79057148e+05],
#        [ 3.43569493e+05],
#        [ 4.56885376e+05],
#        [ 2.68170697e+05],
#        [ 2.95837742e+05],
#        [ 3.16890924e+05],
#        [ 3.07631451e+05],
#        [ 3.16751468e+05],
#        [ 2.96598712e+05],
#        [ 3.05311769e+05],
#        [ 2.00322763e+05],
#        [ 4.70809452e+05],
#        [ 3.42891988e+05],
#        [ 2.68262779e+05],
#        [ 3.31372146e+05],
#        [ 2.04927797e+05],
#        [ 3.55594126e+05],
#        [ 3.49161894e+05],
#        [ 2.34362752e+05],
#        [ 2.42675035e+05],
#        [ 2.49161753e+05],
#        [ 2.30099071e+05],
#        [-2.98222526e+09],
#        [ 1.41861244e+05],
#        [ 3.29635154e+05],
#        [ 2.86609731e+05],
#        [ 1.85736250e+05],
#        [ 3.17470831e+05],
#        [ 2.41484998e+05],
#        [ 2.91949575e+05],
#        [ 5.87697450e+05],
#        [ 1.70917691e+05],
#        [ 2.07563665e+05],
#        [ 5.96835433e+05],
#        [ 3.10851803e+05],
#        [ 2.39400410e+05],
#        [ 2.41264631e+05],
#        [ 3.33313902e+05],
#        [ 2.47230170e+05],
#        [ 2.40161197e+05],
#        [ 3.16483748e+05],
#        [ 4.09875999e+05],
#        [ 2.21472243e+05],
#        [ 2.04046713e+05],
#        [ 2.68992360e+05],
#        [ 3.43229892e+05],
#        [ 2.33889500e+05],
#        [ 2.95281099e+05],
#        [ 2.48652267e+05],
#        [ 3.13744256e+05],
#        [ 2.79408798e+05],
#        [ 2.52766473e+05],
#        [ 1.27779537e+05],
#        [ 2.90685232e+05],
#        [ 4.27465394e+05],
#        [ 2.28032273e+05],
#        [ 6.48906413e+05],
#        [ 2.66815686e+05],
#        [ 3.51511301e+05],
#        [ 2.10988923e+05],
#        [ 3.30570845e+05],
#        [ 2.83342832e+05],
#        [ 3.72239834e+05],
#        [ 2.50345087e+05],
#        [ 5.00076067e+05],
#        [ 2.90194779e+05],
#        [ 3.53140604e+05],
#        [ 3.14525036e+05],
#        [ 2.05523177e+05],
#        [ 3.10422632e+05],
#        [ 2.44789839e+05],
#        [ 3.30234579e+05],
#        [ 2.68061115e+05],
#        [ 2.43531235e+05],
#        [ 2.89469655e+05],
#        [ 2.67792886e+05],
#        [ 1.82769665e+05],
#        [ 1.81600752e+05],
#        [ 4.88700272e+05],
#        [ 3.30512508e+05],
#        [ 1.95098001e+05],
#        [ 5.71780822e+05],
#        [ 2.63886474e+05],
#        [ 2.85112714e+05],
#        [ 2.75032760e+05],
#        [ 2.80302197e+05],
#        [ 3.90925358e+05],
#        [ 3.51589562e+05],
#        [ 2.18049826e+05],
#        [ 3.69897418e+05],
#        [ 2.90869302e+05],
#        [ 3.29181494e+05],
#        [ 2.85876019e+05],
#        [ 2.47943891e+05],
#        [ 3.00466693e+05],
#        [ 4.17271584e+05],
#        [ 2.30214380e+05],
#        [ 2.96550353e+05],
#        [ 2.44560790e+05],
#        [ 2.41296358e+05],
#        [ 2.67332129e+05],
#        [ 2.58648183e+05],
#        [ 2.29189445e+05],
#        [ 3.07016334e+05],
#        [ 2.13783265e+05],
#        [ 2.73473579e+05],
#        [ 2.36527038e+05],
#        [ 3.45675566e+05],
#        [ 1.69820127e+05],
#        [ 2.92673947e+05],
#        [ 2.81025494e+05],
#        [ 2.12752595e+05],
#        [ 2.91589506e+05],
#        [ 2.34237985e+05],
#        [ 1.91749959e+05],
#        [ 1.86954208e+05],
#        [ 1.96601489e+05],
#        [ 1.86398896e+05],
#        [ 2.64557973e+05],
#        [ 3.57001957e+05],
#        [ 4.66775618e+05],
#        [ 4.73223467e+05],
#        [ 2.80333738e+05],
#        [ 4.77335503e+05],
#        [ 3.06814929e+05],
#        [ 2.90857857e+05],
#        [ 3.04059754e+05],
#        [ 5.24141808e+05],
#        [ 2.54745034e+05],
#        [ 1.90449313e+05],
#        [ 2.42067924e+05],
#        [ 3.22961744e+05],
#        [ 2.37758275e+05],
#        [ 3.76455537e+05],
#        [ 2.20580136e+05],
#        [ 3.12708578e+05],
#        [ 2.22402622e+05],
#        [ 2.75439132e+05],
#        [ 2.19656237e+05],
#        [ 3.09283491e+05],
#        [ 2.92953081e+05],
#        [ 3.27160459e+05]])

# %%
merge_data2.to_csv('merged_data.csv', index=False, header=True)

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')
